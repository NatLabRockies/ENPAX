# %% [markdown]
# # Hybrid Solar+BESS and Standalone BESS

# %%
import os
import sys
from pprint import pprint

# 1. Get the absolute path of the folder containing THIS script
current_dir = os.getcwd() # or os.path.dirname(os.path.abspath(__file__)) if in a .py file

# 2. Find the 'ENPAX' root directory
# This looks for the folder that actually contains the 'enpax' package
project_root = current_dir
while project_root != os.path.dirname(project_root): # stop at drive root
    if os.path.exists(os.path.join(project_root, 'enpax')):
        break
    project_root = os.path.dirname(project_root)

# 3. Add that root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# 4. Now the import will work
from enpax.runner import CentralRunner

# 5. Correctly locate your config file relative to that root
config_path = os.path.join(project_root, "configs", "solar_bess_plus_standalone_bess_hybrid.yaml")

result = CentralRunner.from_yaml(config_path).run()
display(result.summary())
# Out:
# {'project': 'Hybrid Solar+BESS and Standalone BESS',
#  'design_by_tech': {'solar_plus_storage': {'solar_capacity_mwdc': 100.0,
#    'solar_inverter_capacity_mwac': 75.75757575757576,
#    'battery_capacity_mwdc': 60.0,
#    'storage_duration_h': 4,
#    'battery_inverter_capacity_mwac': 60.0},
#   'standalone_battery': {'battery_capacity_mwdc': 60,
#    'storage_duration_h': 4,
#    'battery_inverter_capacity_mwac': 60.0}},
#  'capex_by_tech': {'solar_plus_storage': {'total': 1994.9913635012765,
#    'unit': '$/kWdc'},
#   'standalone_battery': {'total': 329.99226874999994, 'unit': '$/kWh-cap'}},
#  'opex_by_tech': {}}

# %%
pprint(result)
# Out:
# SystemResult(project_name='Hybrid Solar+BESS and Standalone BESS',
#              tech_results=[TechResult(tech_name='solar_plus_storage',
#                                       tech_type='solar_bess_2024Q1',
#                                       capex=CapexBreakdown(total=1994.9913635012765,
#                                                            unit='$/kWdc',
#                                                            line_items={'bi_directional_inverter': {'components': {'bi_directional_inverter': 60.0},
#                                                                                                    'total': 60.0},
#                                                                        'ebos': {'components': {'breakers': 14.204545454545453,
#                                                                                                'combiner_boxes': 9.09090909090909,
#                                                                                                'conductors': 15.909090909090908,
#                                                                                                'grounding': 7.196969696969696,
#                                                                                                'network_upgrade': 50.0,
#                                                                                                'shipping': 1.8181818181818181,
#                                                                                                'substation': 31.25,
#                                                                                                'switches': 6.155303030303029,
#                                                                                                'transformers': 30.3030303030303,
#                                                                                                'transmission': 19.67625787878788},
#                                                                                 'total': 185.60428818181816},
#                                                                        'fieldwork': {'components': {'ebos_labor': 61.674757281553404,
#                                                                                                     'equipment_rental': 48.54368932038835,
#                                                                                                     'ess_labor': 218.526,
#                                                                                                     'inspection': 7.766990291262137,
#                                                                                                     'sbos_labor': 71.76699029126216,
#                                                                                                     'site_prep': 38.834951456310684},
#                                                                                      'total': 447.1133786407768},
#                                                                        'li_ion': {'components': {'battery_packs': 60.0,
#                                                                                                  'depreciation': 1.8479999999999999,
#                                                                                                  'electricity': 5.856,
#                                                                                                  'enclosure': 48.0,
#                                                                                                  'labor': 23.952,
#                                                                                                  'li_ion_cells': 231.11999999999998,
#                                                                                                  'maintenance': 0.672,
#                                                                                                  'passthrough_credit': -12.0,
#                                                                                                  'profit': 105.1919999999999,
#                                                                                                  'shipping': 22.56},
#                                                                                   'total': 487.1999999999999},
#                                                                        'officework': {'components': {'engineering': 15.063106796116507,
#                                                                                                      'interconnect': 27.365151515151517,
#                                                                                                      'logistics': 5.582524271844662,
#                                                                                                      'outreach': 6.8543689320388355,
#                                                                                                      'permits': 2.0,
#                                                                                                      'warehousing': 5.33980582524272},
#                                                                                       'total': 62.204957340394245},
#                                                                        'other': {'components': {'contingency': 44.01949309812508,
#                                                                                                 'developer_profit': 94.99958873815604,
#                                                                                                 'management': 22.60779723925003,
#                                                                                                 'sales_tax': 72.58476050074226},
#                                                                                  'total': 234.2116395762734},
#                                                                        'pv_module': {'components': {'cells': 132.6530612244898,
#                                                                                                     'depreciation': 5.31,
#                                                                                                     'electricity': 1.6864077669902913,
#                                                                                                     'frame': 19.303170678256645,
#                                                                                                     'labor': 2.0540453074433658,
#                                                                                                     'maintenance': 1.8,
#                                                                                                     'other_material': 11.92254659539381,
#                                                                                                     'profit': 90.39698201965908,
#                                                                                                     'sheets': 37.37864077669904,
#                                                                                                     'shipping': 33.49514563106796},
#                                                                                      'total': 336.0},
#                                                                        'sbos': {'components': {'control_electronics': 3.407209397375919,
#                                                                                                'dampers': 2.1806140143205885,
#                                                                                                'driven_piers': 27.25767517900735,
#                                                                                                'ess_pad': 9.6,
#                                                                                                'fasteners': 2.097087378640777,
#                                                                                                'module_rails': 9.665778846979983,
#                                                                                                'motor': 13.628837589503677,
#                                                                                                'shipping': 19.417475728155342,
#                                                                                                'slew_drive': 9.292389265570687,
#                                                                                                'torque_tubes': 52.77669902912622},
#                                                                                 'total': 149.32376642868056},
#                                                                        'three_phase_inverter': {'components': {'climate_control': 2.2727272727272725,
#                                                                                                                'depreciation': 0.8939393939393938,
#                                                                                                                'electrical_parts': 3.7878787878787876,
#                                                                                                                'electricity': 0.6378787878787879,
#                                                                                                                'enclosure': 3.0303030303030303,
#                                                                                                                'labor': 5.723484848484848,
#                                                                                                                'maintenance': 0.30303030303030304,
#                                                                                                                'pcb_assemblies': 10.606060606060606,
#                                                                                                                'profit': 5.015530303030302,
#                                                                                                                'shipping': 1.0625},
#                                                                                                 'total': 33.33333333333333}}),
#                                       opex=None,
#                                       design=DesignSummary(line_items={'battery_capacity_mwdc': 60.0,
#                                                                        'battery_inverter_capacity_mwac': 60.0,
#                                                                        'solar_capacity_mwdc': 100.0,
#                                                                        'solar_inverter_capacity_mwac': 75.75757575757576,
#                                                                        'storage_duration_h': 4})),
#                            TechResult(tech_name='standalone_battery',
#                                       tech_type='bess_2025',
#                                       capex=CapexBreakdown(total=329.99226874999994,
#                                                            unit='$/kWh-cap',
#                                                            line_items={'contingency': {'components': {'contingency': 6.8936979166666665},
#                                                                                        'total': 6.8936979166666665},
#                                                                        'developer_profit': {'components': {'profit': 13.787395833333333},
#                                                                                             'total': 13.787395833333333},
#                                                                        'ebos': {'components': {'breaker_dc': 4.6875,
#                                                                                                'conductors': 5.25,
#                                                                                                'grounding': 2.375,
#                                                                                                'network_upgrade': 0.0,
#                                                                                                'scada': 0.875,
#                                                                                                'shipping': 0.6,
#                                                                                                'substation': 10.3125,
#                                                                                                'switch_gear': 2.03125,
#                                                                                                'transformer': 10.0,
#                                                                                                'transmission': 7.083333333333334},
#                                                                                 'total': 43.21458333333334},
#                                                                        'epc_overhead': {'components': {'engineering': 0.16333333333333333,
#                                                                                                        'logistics': 0.9400000000000001,
#                                                                                                        'management': 4.424145833333333,
#                                                                                                        'outreach': 0.36,
#                                                                                                        'warehousing': 0.029333333333333336},
#                                                                                         'total': 5.9168125},
#                                                                        'installation': {'components': {'installation': 2.428066666666667},
#                                                                                         'total': 2.428066666666667},
#                                                                        'interconnection': {'components': {'interconnection': 8.891666666666667},
#                                                                                            'total': 8.891666666666667},
#                                                                        'inverter': {'components': {'bi_directional_inverter': 25.0},
#                                                                                     'total': 25.0},
#                                                                        'li_ion': {'components': {'battery_packs': 25.0,
#                                                                                                  'depreciation': 0.77,
#                                                                                                  'electricity': 2.44,
#                                                                                                  'enclosure': 20.0,
#                                                                                                  'labor': 9.98,
#                                                                                                  'li_ion_cells': 96.3,
#                                                                                                  'maintenance': 0.28,
#                                                                                                  'passthrough_credit': -5.0,
#                                                                                                  'profit': 43.829999999999984,
#                                                                                                  'shipping': 9.4},
#                                                                                   'total': 202.99999999999997},
#                                                                        'permitting': {'components': {'permitting': 0.3333333333333333},
#                                                                                       'total': 0.3333333333333333},
#                                                                        'sales_tax': {'components': {'sales_tax': 15.993379166666665},
#                                                                                      'total': 15.993379166666665},
#                                                                        'sbos': {'components': {'concrete_pads': 3.2,
#                                                                                                'site_prep': 1.3333333333333335},
#                                                                                 'total': 4.533333333333333}}),
#                                       opex=None,
#                                       design=DesignSummary(line_items={'battery_capacity_mwdc': 60,
#                                                                        'battery_inverter_capacity_mwac': 60.0,
#                                                                        'storage_duration_h': 4}))])

# %% [markdown]
# # Standalone BESS

# %%
import os
import sys
from pprint import pprint

# 1. Get the absolute path of the folder containing THIS script
current_dir = os.getcwd() # or os.path.dirname(os.path.abspath(__file__)) if in a .py file

# 2. Find the 'ENPAX' root directory
# This looks for the folder that actually contains the 'enpax' package
project_root = current_dir
while project_root != os.path.dirname(project_root): # stop at drive root
    if os.path.exists(os.path.join(project_root, 'enpax')):
        break
    project_root = os.path.dirname(project_root)

# 3. Add that root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# 4. Now the import will work
from enpax.runner import CentralRunner

# 5. Correctly locate your config file relative to that root
config_path = os.path.join(project_root, "configs", "standalone_battery.yaml")

result = CentralRunner.from_yaml(config_path).run()
display(result.summary())
# Out:
# {'project': 'Standalone BESS',
#  'design_by_tech': {'standalone_battery': {'battery_capacity_mwdc': 60,
#    'storage_duration_h': 4,
#    'battery_inverter_capacity_mwac': 60.0}},
#  'capex_by_tech': {'standalone_battery': {'total': 321.1006020833333,
#    'unit': '$/kWh-cap'}},
#  'opex_by_tech': {}}

# %%
pprint(result)
# Out:
# SystemResult(project_name='Standalone BESS',
#              tech_results=[TechResult(tech_name='standalone_battery',
#                                       tech_type='bess_2025',
#                                       capex=CapexBreakdown(total=321.1006020833333,
#                                                            unit='$/kWh-cap',
#                                                            line_items={'contingency': {'components': {'contingency': 6.8936979166666665},
#                                                                                        'total': 6.8936979166666665},
#                                                                        'developer_profit': {'components': {'profit': 13.787395833333333},
#                                                                                             'total': 13.787395833333333},
#                                                                        'ebos': {'components': {'breaker_dc': 4.6875,
#                                                                                                'conductors': 5.25,
#                                                                                                'grounding': 2.375,
#                                                                                                'network_upgrade': 0.0,
#                                                                                                'scada': 0.875,
#                                                                                                'shipping': 0.6,
#                                                                                                'substation': 10.3125,
#                                                                                                'switch_gear': 2.03125,
#                                                                                                'transformer': 10.0,
#                                                                                                'transmission': 7.083333333333334},
#                                                                                 'total': 43.21458333333334},
#                                                                        'epc_overhead': {'components': {'engineering': 0.16333333333333333,
#                                                                                                        'logistics': 0.9400000000000001,
#                                                                                                        'management': 4.424145833333333,
#                                                                                                        'outreach': 0.36,
#                                                                                                        'warehousing': 0.029333333333333336},
#                                                                                         'total': 5.9168125},
#                                                                        'installation': {'components': {'installation': 2.428066666666667},
#                                                                                         'total': 2.428066666666667},
#                                                                        'interconnection': {'components': {'interconnection': 0.0},
#                                                                                            'total': 0.0},
#                                                                        'inverter': {'components': {'bi_directional_inverter': 25.0},
#                                                                                     'total': 25.0},
#                                                                        'li_ion': {'components': {'battery_packs': 25.0,
#                                                                                                  'depreciation': 0.77,
#                                                                                                  'electricity': 2.44,
#                                                                                                  'enclosure': 20.0,
#                                                                                                  'labor': 9.98,
#                                                                                                  'li_ion_cells': 96.3,
#                                                                                                  'maintenance': 0.28,
#                                                                                                  'passthrough_credit': -5.0,
#                                                                                                  'profit': 43.829999999999984,
#                                                                                                  'shipping': 9.4},
#                                                                                   'total': 202.99999999999997},
#                                                                        'permitting': {'components': {'permitting': 0.3333333333333333},
#                                                                                       'total': 0.3333333333333333},
#                                                                        'sales_tax': {'components': {'sales_tax': 15.993379166666665},
#                                                                                      'total': 15.993379166666665},
#                                                                        'sbos': {'components': {'concrete_pads': 3.2,
#                                                                                                'site_prep': 1.3333333333333335},
#                                                                                 'total': 4.533333333333333}}),
#                                       opex=None,
#                                       design=DesignSummary(line_items={'battery_capacity_mwdc': 60,
#                                                                        'battery_inverter_capacity_mwac': 60.0,
#                                                                        'storage_duration_h': 4}))])

# %% [markdown]
# # Standalone Solar

# %%
import os
import sys
from pprint import pprint

# 1. Get the absolute path of the folder containing THIS script
current_dir = os.getcwd() # or os.path.dirname(os.path.abspath(__file__)) if in a .py file

# 2. Find the 'ENPAX' root directory
# This looks for the folder that actually contains the 'enpax' package
project_root = current_dir
while project_root != os.path.dirname(project_root): # stop at drive root
    if os.path.exists(os.path.join(project_root, 'enpax')):
        break
    project_root = os.path.dirname(project_root)

# 3. Add that root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# 4. Now the import will work
from enpax.runner import CentralRunner

# 5. Correctly locate your config file relative to that root
config_path = os.path.join(project_root, "configs", "standalone_solar.yaml")

result = CentralRunner.from_yaml(config_path).run()
from pprint import pprint


display(result.summary())
# Out:
# {'project': 'Standalone Solar',
#  'design_by_tech': {'standalone_solar': {'solar_capacity_mwdc': 100.0,
#    'solar_inverter_capacity_mwac': 75.75757575757576}},
#  'capex_by_tech': {'standalone_solar': {'total': 1118.4967130012765,
#    'unit': '$/kWdc'}},
#  'opex_by_tech': {}}

# %%
pprint(result)
# Out:
# SystemResult(project_name='Standalone Solar',
#              tech_results=[TechResult(tech_name='standalone_solar',
#                                       tech_type='solar_bess_2024Q1',
#                                       capex=CapexBreakdown(total=1118.4967130012765,
#                                                            unit='$/kWdc',
#                                                            line_items={'bi_directional_inverter': {'components': {'bi_directional_inverter': 0.0},
#                                                                                                    'total': 0.0},
#                                                                        'ebos': {'components': {'breakers': 14.204545454545453,
#                                                                                                'combiner_boxes': 9.09090909090909,
#                                                                                                'conductors': 15.909090909090908,
#                                                                                                'grounding': 7.196969696969696,
#                                                                                                'network_upgrade': 50.0,
#                                                                                                'shipping': 1.8181818181818181,
#                                                                                                'substation': 31.25,
#                                                                                                'switches': 6.155303030303029,
#                                                                                                'transformers': 30.3030303030303,
#                                                                                                'transmission': 19.67625787878788},
#                                                                                 'total': 185.60428818181816},
#                                                                        'fieldwork': {'components': {'ebos_labor': 61.674757281553404,
#                                                                                                     'equipment_rental': 48.54368932038835,
#                                                                                                     'ess_labor': 0.0,
#                                                                                                     'inspection': 7.766990291262137,
#                                                                                                     'sbos_labor': 71.76699029126216,
#                                                                                                     'site_prep': 38.834951456310684},
#                                                                                      'total': 228.58737864077673},
#                                                                        'li_ion': {'components': {'battery_packs': 0.0,
#                                                                                                  'depreciation': 0.0,
#                                                                                                  'electricity': 0.0,
#                                                                                                  'enclosure': 0.0,
#                                                                                                  'labor': 0.0,
#                                                                                                  'li_ion_cells': 0.0,
#                                                                                                  'maintenance': 0.0,
#                                                                                                  'passthrough_credit': -0.0,
#                                                                                                  'profit': 0.0,
#                                                                                                  'shipping': 0.0},
#                                                                                   'total': 0.0},
#                                                                        'officework': {'components': {'engineering': 15.063106796116507,
#                                                                                                      'interconnect': 27.365151515151517,
#                                                                                                      'logistics': 5.582524271844662,
#                                                                                                      'outreach': 6.8543689320388355,
#                                                                                                      'permits': 2.0,
#                                                                                                      'warehousing': 5.33980582524272},
#                                                                                       'total': 62.204957340394245},
#                                                                        'other': {'components': {'contingency': 24.636343098125078,
#                                                                                                 'developer_profit': 53.261748238156024,
#                                                                                                 'management': 14.85453723925003,
#                                                                                                 'sales_tax': 40.29036050074227},
#                                                                                  'total': 133.0429890762734},
#                                                                        'pv_module': {'components': {'cells': 132.6530612244898,
#                                                                                                     'depreciation': 5.31,
#                                                                                                     'electricity': 1.6864077669902913,
#                                                                                                     'frame': 19.303170678256645,
#                                                                                                     'labor': 2.0540453074433658,
#                                                                                                     'maintenance': 1.8,
#                                                                                                     'other_material': 11.92254659539381,
#                                                                                                     'profit': 90.39698201965908,
#                                                                                                     'sheets': 37.37864077669904,
#                                                                                                     'shipping': 33.49514563106796},
#                                                                                      'total': 336.0},
#                                                                        'sbos': {'components': {'control_electronics': 3.407209397375919,
#                                                                                                'dampers': 2.1806140143205885,
#                                                                                                'driven_piers': 27.25767517900735,
#                                                                                                'ess_pad': 0.0,
#                                                                                                'fasteners': 2.097087378640777,
#                                                                                                'module_rails': 9.665778846979983,
#                                                                                                'motor': 13.628837589503677,
#                                                                                                'shipping': 19.417475728155342,
#                                                                                                'slew_drive': 9.292389265570687,
#                                                                                                'torque_tubes': 52.77669902912622},
#                                                                                 'total': 139.72376642868053},
#                                                                        'three_phase_inverter': {'components': {'climate_control': 2.2727272727272725,
#                                                                                                                'depreciation': 0.8939393939393938,
#                                                                                                                'electrical_parts': 3.7878787878787876,
#                                                                                                                'electricity': 0.6378787878787879,
#                                                                                                                'enclosure': 3.0303030303030303,
#                                                                                                                'labor': 5.723484848484848,
#                                                                                                                'maintenance': 0.30303030303030304,
#                                                                                                                'pcb_assemblies': 10.606060606060606,
#                                                                                                                'profit': 5.015530303030302,
#                                                                                                                'shipping': 1.0625},
#                                                                                                 'total': 33.33333333333333}}),
#                                       opex=None,
#                                       design=DesignSummary(line_items={'solar_capacity_mwdc': 100.0,
#                                                                        'solar_inverter_capacity_mwac': 75.75757575757576}))])

# %% [markdown]
# # Solar+BESS

# %%
import os
import sys
from pprint import pprint

# 1. Get the absolute path of the folder containing THIS script
current_dir = os.getcwd() # or os.path.dirname(os.path.abspath(__file__)) if in a .py file

# 2. Find the 'ENPAX' root directory
# This looks for the folder that actually contains the 'enpax' package
project_root = current_dir
while project_root != os.path.dirname(project_root): # stop at drive root
    if os.path.exists(os.path.join(project_root, 'enpax')):
        break
    project_root = os.path.dirname(project_root)

# 3. Add that root to sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

# 4. Now the import will work
from enpax.runner import CentralRunner

# 5. Correctly locate your config file relative to that root
config_path = os.path.join(project_root, "configs", "solar_bess.yaml")

result = CentralRunner.from_yaml(config_path).run()
from pprint import pprint


display(result.summary())
# Out:
# {'project': 'Solar + BESS',
#  'design_by_tech': {'solar_plus_storage': {'solar_capacity_mwdc': 100.0,
#    'solar_inverter_capacity_mwac': 75.75757575757576,
#    'battery_capacity_mwdc': 60.0,
#    'storage_duration_h': 4,
#    'battery_inverter_capacity_mwac': 60.0}},
#  'capex_by_tech': {'solar_plus_storage': {'total': 1994.9913635012765,
#    'unit': '$/kWdc'}},
#  'opex_by_tech': {}}

# %%
pprint(result)
# Out:
# SystemResult(project_name='Solar + BESS',
#              tech_results=[TechResult(tech_name='solar_plus_storage',
#                                       tech_type='solar_bess_2024Q1',
#                                       capex=CapexBreakdown(total=1994.9913635012765,
#                                                            unit='$/kWdc',
#                                                            line_items={'bi_directional_inverter': {'components': {'bi_directional_inverter': 60.0},
#                                                                                                    'total': 60.0},
#                                                                        'ebos': {'components': {'breakers': 14.204545454545453,
#                                                                                                'combiner_boxes': 9.09090909090909,
#                                                                                                'conductors': 15.909090909090908,
#                                                                                                'grounding': 7.196969696969696,
#                                                                                                'network_upgrade': 50.0,
#                                                                                                'shipping': 1.8181818181818181,
#                                                                                                'substation': 31.25,
#                                                                                                'switches': 6.155303030303029,
#                                                                                                'transformers': 30.3030303030303,
#                                                                                                'transmission': 19.67625787878788},
#                                                                                 'total': 185.60428818181816},
#                                                                        'fieldwork': {'components': {'ebos_labor': 61.674757281553404,
#                                                                                                     'equipment_rental': 48.54368932038835,
#                                                                                                     'ess_labor': 218.526,
#                                                                                                     'inspection': 7.766990291262137,
#                                                                                                     'sbos_labor': 71.76699029126216,
#                                                                                                     'site_prep': 38.834951456310684},
#                                                                                      'total': 447.1133786407768},
#                                                                        'li_ion': {'components': {'battery_packs': 60.0,
#                                                                                                  'depreciation': 1.8479999999999999,
#                                                                                                  'electricity': 5.856,
#                                                                                                  'enclosure': 48.0,
#                                                                                                  'labor': 23.952,
#                                                                                                  'li_ion_cells': 231.11999999999998,
#                                                                                                  'maintenance': 0.672,
#                                                                                                  'passthrough_credit': -12.0,
#                                                                                                  'profit': 105.1919999999999,
#                                                                                                  'shipping': 22.56},
#                                                                                   'total': 487.1999999999999},
#                                                                        'officework': {'components': {'engineering': 15.063106796116507,
#                                                                                                      'interconnect': 27.365151515151517,
#                                                                                                      'logistics': 5.582524271844662,
#                                                                                                      'outreach': 6.8543689320388355,
#                                                                                                      'permits': 2.0,
#                                                                                                      'warehousing': 5.33980582524272},
#                                                                                       'total': 62.204957340394245},
#                                                                        'other': {'components': {'contingency': 44.01949309812508,
#                                                                                                 'developer_profit': 94.99958873815604,
#                                                                                                 'management': 22.60779723925003,
#                                                                                                 'sales_tax': 72.58476050074226},
#                                                                                  'total': 234.2116395762734},
#                                                                        'pv_module': {'components': {'cells': 132.6530612244898,
#                                                                                                     'depreciation': 5.31,
#                                                                                                     'electricity': 1.6864077669902913,
#                                                                                                     'frame': 19.303170678256645,
#                                                                                                     'labor': 2.0540453074433658,
#                                                                                                     'maintenance': 1.8,
#                                                                                                     'other_material': 11.92254659539381,
#                                                                                                     'profit': 90.39698201965908,
#                                                                                                     'sheets': 37.37864077669904,
#                                                                                                     'shipping': 33.49514563106796},
#                                                                                      'total': 336.0},
#                                                                        'sbos': {'components': {'control_electronics': 3.407209397375919,
#                                                                                                'dampers': 2.1806140143205885,
#                                                                                                'driven_piers': 27.25767517900735,
#                                                                                                'ess_pad': 9.6,
#                                                                                                'fasteners': 2.097087378640777,
#                                                                                                'module_rails': 9.665778846979983,
#                                                                                                'motor': 13.628837589503677,
#                                                                                                'shipping': 19.417475728155342,
#                                                                                                'slew_drive': 9.292389265570687,
#                                                                                                'torque_tubes': 52.77669902912622},
#                                                                                 'total': 149.32376642868056},
#                                                                        'three_phase_inverter': {'components': {'climate_control': 2.2727272727272725,
#                                                                                                                'depreciation': 0.8939393939393938,
#                                                                                                                'electrical_parts': 3.7878787878787876,
#                                                                                                                'electricity': 0.6378787878787879,
#                                                                                                                'enclosure': 3.0303030303030303,
#                                                                                                                'labor': 5.723484848484848,
#                                                                                                                'maintenance': 0.30303030303030304,
#                                                                                                                'pcb_assemblies': 10.606060606060606,
#                                                                                                                'profit': 5.015530303030302,
#                                                                                                                'shipping': 1.0625},
#                                                                                                 'total': 33.33333333333333}}),
#                                       opex=None,
#                                       design=DesignSummary(line_items={'battery_capacity_mwdc': 60.0,
#                                                                        'battery_inverter_capacity_mwac': 60.0,
#                                                                        'solar_capacity_mwdc': 100.0,
#                                                                        'solar_inverter_capacity_mwac': 75.75757575757576,
#                                                                        'storage_duration_h': 4}))])
